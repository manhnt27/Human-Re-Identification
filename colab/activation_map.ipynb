# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/deep-person-reid-backup/log/actmap_dukemtmcreid/
# Out:
# /content/drive/MyDrive/deep-person-reid-backup/log/actmap_dukemtmcreid

# %%
# !pip install ipython

# %%
from IPython.display import Image, display
display(Image('0742_c1_f0186814.jpg'))

# %%
display(Image('0804_c1_f0204460.jpg'))

# %%
display(Image('0184_c3_f0062029.jpg'))

# %%
display(Image('0095_c1_f0069780.jpg'))

# %%
display(Image('0552_c3_f0125186.jpg'))

# %%
display(Image('0488_c1_f0127852.jpg'))

# %%
display(Image('0429_c2_f0119061.jpg'))

# %%
display(Image('4152_c7_f0056763.jpg'))

# %%
display(Image('5867_c8_f0009764.jpg'))

# %%
display(Image('5867_c8_f0009884.jpg'))
